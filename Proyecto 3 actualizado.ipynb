# %% [markdown]
# PROYECTO KATAS: PYTHON

# %% [markdown]
# 1. Escribe una función que reciba una cadena de texto como parámetro y devuelva un diccionario con las frecuencias de cada letra en la cadena. Los espacios no deben ser considerados.

# %%
def contar_letras(texto):
    conteo = {}
    for letra in texto:
        if letra != " ":
            conteo[letra] = conteo.get(letra, 0) + 1
    return conteo

# %%
ciudad = "Barcelona"
contar_letras(ciudad)
# Out:
# {'B': 1, 'a': 2, 'r': 1, 'c': 1, 'e': 1, 'l': 1, 'o': 1, 'n': 1}

# %% [markdown]
# 2. Dada una lista de números, obtén una nueva lista con el doble de cada valor. Usa la función map()

# %%
nums = [1, 2, 3, 4, 8]
list(map(lambda x: x*2, nums))
# Out:
# [2, 4, 6, 8, 16]

# %% [markdown]
# 3. Escribe una función que tome una lista de palabras y una palabra objetivo como parámetros. La función debe
# devolver una lista con todas las palabras de la lista original que contengan la palabra objetivo.

# %%
def buscar_palabras(lista_palabras, palabra_objetivo):
    resultado = []
    for palabra in lista_palabras:
        if palabra_objetivo in palabra:
            resultado.append(palabra)
    return resultado

# %%
lista = ["casa", "casamiento", "perro", "casero", "gato"]
print(buscar_palabras(lista, "casa"))
# Out:
# ['casa', 'casamiento']

# %% [markdown]
# 4. Genera una función que calcule la diferencia entre los valores de dos listas. Usa la función map()

# %%
from operator import sub

def diferencia_listas(lista1, lista2):
    """Devuelve una lista con lista1[i] - lista2[i] para cada i.
    Si las listas tienen longitudes distintas, se ignoran los sobrantes."""
    return list(map(sub, lista1, lista2))


print(diferencia_listas([10, 20, 30], [1, 2, 3]))     
print(diferencia_listas([5, 4, 3, 2], [1, 1]))
# Out:
# [9, 18, 27]
# [4, 3]

# %% [markdown]
# 5. Escribe una función que tome una lista de números como parámetro y un valor opcional nota_aprobado, que por defecto es 5. La función debe calcular la media de los números en la lista y determinar si la media es mayor o igual
# que nota aprobado. Si es así, el estado será "aprobado", de lo contrario, será "suspenso". La función debe devolver
# una tupla que contenga la media y el estado.

# %%
def nota(lista_numeros,nota_aprobado=5):
    media = sum(lista_numeros)/len(lista_numeros)
    if media >=nota_aprobado:
        estado="aprobado"
    else: 
        estado="suspenso"
    return media, estado

# %%
resultado =nota ([2,5,6,8,9])
print(resultado)
# Out:
# (6.0, 'aprobado')

# %% [markdown]
# 6. Escribe una función que calcule el factorial de un número de manera recursiva

# %%
def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

# %%
numero =10
factorial(numero)
# Out:
# 3628800

# %% [markdown]
# 7. Genera una función que convierta una lista de tuplas a una lista de strings. Usa la función map()

# %%
def tuplas_a_strings(lista_tuplas):
    return list(map(str, lista_tuplas))

# %%
tuplas = [(1, 2), ("a", "b"), (3, 4)]
print(tuplas_a_strings(tuplas))
# Out:
# ['(1, 2)', "('a', 'b')", '(3, 4)']

# %% [markdown]
# 8. Escribe un programa que pida al usuario dos números e intente dividirlos. Si el usuario ingresa un valor no numérico
# o intenta dividir por cero, maneja esas excepciones de manera adecuada. Asegúrate de mostrar un mensaje
# indicando si la división fue exitosa o no.

# %%
try:
    numero_1 = int(input("Introduce el primer número: "))
    numero_2 = int(input("Introduce el segundo número: "))
    division = numero_1 / numero_2
    print(f"El resultado es {division}")
except ValueError:
    print("Has introducido un valor no numérico")
except ZeroDivisionError:
    print("No se puede dividir entre cero")
# Out:
# El resultado es 1.0

# %% [markdown]
# 9. Escribe una función que tome una lista de nombres de mascotas como parámetro y devuelva una nueva lista
# excluyendo ciertas mascotas prohibidas en España. La lista de mascotas a excluir es ["Mapache", "Tigre",
# "Serpiente Pitón", "Cocodrilo", "Oso"].Usa la función filter()

# %%
def mascotas_permitidas(lista_mascotas):
    prohibidas = ["Mapache", "Tigre", "Serpiente Pitón", "Cocodrilo", "Oso"]
    return list(filter(lambda mascota: mascota not in prohibidas, lista_mascotas))

# %%
mascotas = ["Perro", "Gato", "Mapache", "Conejo", "Oso"]
print(mascotas_permitidas(mascotas))
# Out:
# ['Perro', 'Gato', 'Conejo']

# %% [markdown]
# 10. Escribe una función que reciba una lista de números y calcule su promedio. Si la lista está vacía, lanza una
# excepción personalizada y maneja el error adecuadamente.

# %%
class ListaVaciaError(Exception):
    pass

def promedio(lista):
    if lista == []:
        raise ListaVaciaError("La lista está vacía")
    return sum(lista) / len(lista)

# %%
try:
    print(promedio([]))
except ListaVaciaError as e:
    print(e)
# Out:
# La lista está vacía

# %%
nums = [4]
print(promedio(nums))
# Out:
# 4.0

# %% [markdown]
# 11. Escribe un programa que pida al usuario que introduzca su edad. Si el usuario ingresa un valor no numérico o un
# valor fuera del rango esperado (por ejemplo, menor que 0 o mayor que 120), maneja las excepciones
# adecuadamente

# %%
try:
    edad= int(input("La edad que tengo es:"))
    if edad <0 or edad >120:
        print("Error: Introduce dentro del rango")
    else: 
        print(f"Tengo {edad} años")
except ValueError:
    print("Debes introducir un numero")
# Out:
# Debes introducir un numero

# %% [markdown]
# 12. Genera una función que al recibir una frase devuelva una lista con la longitud de cada palabra. Usa la función map()

# %%
def longitud_palabra(strings):
    return list(map(lambda x: len(x), strings))

# %%
lista= ["Maria","Paula","Sergio"]
print(longitud_palabra(lista))
# Out:
# [5, 5, 6]

# %% [markdown]
# 13. Genera una función la cual, para un conjunto de caracteres, devuelva una lista de tuplas con cada letra en
# mayúsculas y minúsculas. Las letras no pueden estar repetidas .Usa la función map()

# %%
def letras_tuplas(caracteres):
    unicas = []

    for letra in caracteres:
        if letra.lower() not in unicas:
            unicas.append(letra.lower())

    return list(map(lambda x: (x.upper(), x.lower()), unicas))

# %%
lista = "GGgrfsslosd"
letras_tuplas(lista)
# Out:
# [('G', 'g'),
#  ('R', 'r'),
#  ('F', 'f'),
#  ('S', 's'),
#  ('L', 'l'),
#  ('O', 'o'),
#  ('D', 'd')]

# %% [markdown]
# 14. Crea una función que retorne las palabras de una lista de palabras que comience con una letra en especifico. Usa la
# función filter()

# %%
def palabras(lista_palabras):
    letra = "P"
    return list(filter(lambda nombre: nombre.startswith("P"), lista_palabras))

# %%
amigos =["Maria","Paula","Peppe","Carlos","Pablo"]
print(palabras(amigos))
# Out:
# ['Paula', 'Peppe', 'Pablo']

# %% [markdown]
# 15. Crea una función lambda que sume 3 a cada número de una lista dada

# %%
nums= [4,5,8,9,12,15]
list(map(lambda x: x+3, nums))
# Out:
# [7, 8, 11, 12, 15, 18]

# %% [markdown]
# 16. Escribe una función que tome una cadena de texto y un número entero n como parámetros y devuelva una lista de
# todas las palabras que sean más largas que n. Usa la función filter()

# %%
def longitud(strings,n):
    return list(filter(lambda x: len(x)>n, strings))

# %%
lista= ["Comida","Bebida","Postre","Hoy"]
n=3
print(longitud(lista,n))
# Out:
# ['Comida', 'Bebida', 'Postre']

# %% [markdown]
# 17. Crea una función que tome una lista de dígitos y devuelva el número correspondiente. Por ejemplo, [5,7,2]
# corresponde al número quinientos setenta y dos (572). Usa la función reduce()

# %%
from functools import reduce

numeros = [5, 7, 2]
resultado = reduce(lambda x, y: x * 10 + y, numeros)
print(resultado)
# Out:
# 572

# %% [markdown]
# 18. Escribe un programa en Python que cree una lista de diccionarios que contenga información de estudiantes
# (nombre, edad, calificación) y use la función filter para extraer a los estudiantes con una calificación mayor o igual a
# "90". Usa la función filter()

# %%
lista_empleados = [
    {"nombre": "Jose Perez", "edad": 19,"calificacion":70},
    {"nombre": "Pablo Gomez", "edad": 23,"calificacion":93},
    {"nombre": "Luis Martin", "edad": 23,"calificacion":88}
    ]
resultado = list(filter(lambda x: x["calificacion"] >= 90, lista_empleados))
print(resultado)
# Out:
# [{'nombre': 'Pablo Gomez', 'edad': 23, 'calificacion': 93}]

# %% [markdown]
# 19. Crea una función lambda que filtre los números impares de una lista dada

# %%
def impares(numeros):
    return list(filter(lambda x: x%2, numeros))

# %%
nums= [4,5,8,9,12,15,23,27,32]
impares(nums)
# Out:
# [5, 9, 15, 23, 27]

# %% [markdown]
# 20. Para una lista con elementos tipo integer y string obtén una nueva lista sólo con los valores int. Usa la función
# filter()

# %%
lista= [4,5,8,9,12,15,"Comida","Bebida","Postre"]
list(filter(lambda x: type(x) ==int, lista))
# Out:
# [4, 5, 8, 9, 12, 15]

# %% [markdown]
# 21. Crea una función que calcule el cubo de un número dado mediante una función lambda

# %%
nums= [4,5,8,9,12,15]
list(map(lambda x: x**3, nums))
# Out:
# [64, 125, 512, 729, 1728, 3375]

# %% [markdown]
# 22. Dada una lista numérica, obtén el producto total de los valores de dicha lista.Usa la función reduce() .

# %%
from functools import reduce
def producto (num_1,num_2):
    producto_total = num_1 * num_2
    return producto_total

# %%
numeros = [55, 11]

resultado_reduce = reduce(producto, numeros)
print(f"El resultado de la función reduce es: {resultado_reduce}")
# Out:
# El resultado de la función reduce es: 605

# %% [markdown]
# 23. Concatena una lista de palabras.Usa la función reduce() .

# %%
from functools import reduce
def concat(string_1, string_2):
    concatenar= string_1+ " " + string_2
    return concatenar

# %%
lista_palabras = ["Hola", "que tal","todo bien","mañana te veo"]

resultado_reduce = reduce(concat, lista_palabras)
print(f"El resultado de la función reduce es: {resultado_reduce}")
# Out:
# El resultado de la función reduce es: Hola que tal todo bien mañana te veo

# %% [markdown]
# 24. Calcula la diferencia total en los valores de una lista. Usa la función reduce() .

# %%
from functools import reduce
def diferencia (num_1,num_2):
    diferencia_total = num_1-num_2
    return diferencia_total

# %%
numeros = [23, 10]

resultado_reduce = reduce(diferencia, numeros)
print(f"El resultado de la función reduce es: {resultado_reduce}")
# Out:
# El resultado de la función reduce es: 13

# %% [markdown]
# 25. Crea una función que cuente el número de caracteres en una cadena de texto dada.

# %%
def num_caracteres(string):
    return len(string)
num_caracteres("Pablo")
# Out:
# 5

# %% [markdown]
# 26. Crea una función lambda que calcule el resto de la división entre dos números dados.

# %%
numero1 =[10]
numero2=[5]

list(map(lambda x,y: x%y,numero1, numero2))
# Out:
# [0]

# %% [markdown]
# 27.  Crea una función que calcule el promedio de una lista de números.

# %%
def promedio(numeros):
    return sum(numeros)/len(numeros)  

promedio([1,2,3,4,6,7,10])
# Out:
# 4.714285714285714

# %% [markdown]
# 28. Crea una función que busque y devuelva el primer elemento duplicado en una lista dada

# %%
def primer_duplicado(lista):
    vistos = []

    for elemento in lista:
        if elemento in vistos:
            return elemento
        vistos.append(elemento)

    return None

# %%
print(primer_duplicado([4, 1, 1, 7, 3, 1]))
# Out:
# 1

# %% [markdown]
# 29. Crea una función que convierta una variable en una cadena de texto y enmascare todos los caracteres con el
# carácter '#', excepto los últimos cuatro

# %%
def variable(string):
    cadena_texto = str(string)
    if len(cadena_texto) <= 4:
        return cadena_texto
    return "#" * (len(cadena_texto) - 4) + cadena_texto[-4:]

# %%
x ="Python"
variable(x)
# Out:
# '##thon'

# %% [markdown]
# 30. Crea una función que determine si dos palabras son anagramas, es decir, si están formadas por las mismas letras
# pero en diferente orden.

# %%
def son_anagramas(palabra1, palabra2):
    palabra1 = palabra1.lower()
    palabra2 = palabra2.lower()

    return sorted(palabra1) == sorted(palabra2)

# %%
print(son_anagramas("roma", "amor"))
print(son_anagramas("perro", "gato"))
# Out:
# True
# False

# %% [markdown]
# 31. Crea una función que solicite al usuario ingresar una lista de nombres y luego solicite un nombre para buscar en
# esa lista. Si el nombre está en la lista, se imprime un mensaje indicando que fue encontrado, de lo contrario, se
# lanza una excepción

# %%
def usuario(lista, nombre):
    if nombre in lista:
        print("La persona ha sido encontrada")
    else:
        raise Exception("La persona no ha sido encontrada en la lista")

lista = input("Dame una lista de nombres separadas por coma: ").split(",")
nombre = input("¿A quién estás buscando?: ")

usuario(lista, nombre)
# Out:
# La persona ha sido encontrada

# %% [markdown]
# 32. Crea una función que tome un nombre completo y una lista de empleados, busque el nombre completo en la lista y
# devuelve el puesto del empleado si está en la lista, de lo contrario, devuelve un mensaje indicando que la persona
# no trabaja aquí.

# %%
def empleado(nombre_completo, lista_empleados):
    for empleado in lista_empleados:
        if empleado["nombre"].lower() == nombre_completo.lower():
            return empleado["puesto"]
    return "La persona no trabaja aquí"

# %%
lista_empleados = [
    {"nombre": "Jose Perez", "puesto": "RRHH"},
    {"nombre": "Pablo Gomez", "puesto": "Contabilidad"},
    {"nombre": "Luis Martin", "puesto": "Informática"}
]

print(empleado("Pablo Gomez", lista_empleados))
print(empleado("Ana Lopez", lista_empleados))
# Out:
# Contabilidad
# La persona no trabaja aquí

# %% [markdown]
# 33. Crea una función lambda que sume elementos correspondientes de dos listas dadas

# %%
lista= ["Maria ten cuidado "]
lista2_= ["pasan los coches muy rapido"]
list(map(lambda x, y: x+y, lista,lista2_))
# Out:
# ['Maria ten cuidado pasan los coches muy rapido']

# %% [markdown]
# 34. Crea la clase Arbol , define un árbol genérico con un tronco y ramas como atributos. Los métodos disponibles son:
# crecer_tronco , nueva_rama , crecer_ramas , quitar_rama e info_arbol . El objetivo es implementar estos métodos para
# manipular la estructura del árbol.
# Código a seguir:
# 1. Inicializar un árbol con un tronco de longitud 1 y una lista vacía de ramas.
# 2. Implementar el método crecer_tronco para aumentar la longitud del tronco en una unidad.
# 3. Implementar el método nueva_rama para agregar una nueva rama de longitud 1 a la lista de ramas.
# 4. Implementar el método crecer_ramas para aumentar en una unidad la longitud de todas las ramas existentes.
# 5. Implementar el método quitar_rama para eliminar una rama en una posición específica.
# 6. Implementar el método
# info_arbol para devolver información sobre la longitud del tronco, el número de ramas y las longitudes de las
# mismas.
# Caso de uso:
# 1. Crear un árbol.
# 2. Hacer crecer el tronco del árbol una unidad.
# 3. Añadir una nueva rama al árbol.
# 4. Hacer crecer todas las ramas del árbol una unidad.
# 5. Añadir dos nuevas ramas al árbol.
# 6. Retirar la rama situada en la posición 2.
# 7. Obtener información sobre el árbol.

# %%
class Arbol:
    def __init__(self):
        self.tronco = 1
        self.ramas = []

    def crecer_tronco(self):
        self.tronco += 1

    def nueva_rama(self):
        self.ramas.append(1)

    def crecer_ramas(self):
        self.ramas = [rama + 1 for rama in self.ramas]

    def quitar_rama(self, posicion):
        if 0 <= posicion < len(self.ramas):
            self.ramas.pop(posicion)
        else:
            print("Posición no válida")

    def info_arbol(self):
        return {
            "longitud_tronco": self.tronco,
            "numero_ramas": len(self.ramas),
            "longitudes_ramas": self.ramas
        }

# %%
arbol = Arbol()

arbol.crecer_tronco()   
arbol.nueva_rama()     
arbol.crecer_ramas()    
arbol.nueva_rama()      
arbol.nueva_rama()      
arbol.quitar_rama(2)    

print(arbol.info_arbol())
# Out:
# {'longitud_tronco': 2, 'numero_ramas': 2, 'longitudes_ramas': [2, 1]}

# %% [markdown]
# 36. Crea la clase UsuarioBanco ,representa a un usuario de un banco con su nombre, saldo y si tiene o no cuenta
# corriente. Proporciona métodos para realizar operaciones como retirar dinero, transferir dinero desde otro usuario y
# agregar dinero al saldo.
# Código a seguir:
# 1. Inicializar un usuario con su nombre, saldo y si tiene o no cuenta corriente mediante True y False .
# 2. Implementar el método retirar_dinero para retirar dinero del saldo del usuario. Lanzará un error en caso de no
# poder hacerse.
# 3. Implementar el método transferir_dinero para realizar una transferencia desde otro usuario al usuario actual.
# Lanzará un error en caso de no poder hacerse.
# 4. Implementar el método agregar_dinero para agregar dinero al saldo del usuario.
# Caso de uso:
# 1. Crear dos usuarios: "Alicia" con saldo inicial de 100 y "Bob" con saldo inicial de 50, ambos con cuenta corriente.
# PROYECTO LÓGICA: Katas de Python 3
# 2. Agregar 20 unidades de saldo de "Bob".
# 3. Hacer una transferencia de 80 unidades desde "Bob" a "Alicia".
# 4. Retirar 50 unidades de saldo a "Alicia"

# %%
class UsuarioBanco:
    def __init__(self, nombre, saldo, cuenta_corriente):
        self.nombre = nombre
        self.saldo = saldo
        self.cuenta_corriente = cuenta_corriente

    def retirar_dinero(self, cantidad):
        if not self.cuenta_corriente:
            raise Exception("No tiene cuenta corriente")
        if cantidad > self.saldo:
            raise Exception("Saldo insuficiente")
        self.saldo -= cantidad

    def transferir_dinero(self, otro_usuario, cantidad):
        if otro_usuario.cuenta_corriente == False or self.cuenta_corriente == False:
            print("Alguno de los usuarios no tiene cuenta corriente")
        elif cantidad > otro_usuario.saldo:
            print("El usuario que transfiere no tiene saldo suficiente")
        else:
            otro_usuario.saldo -= cantidad
            self.saldo += cantidad

    def agregar_dinero(self, cantidad):
        self.saldo += cantidad


alicia = UsuarioBanco("Alicia", 100, True)
bob = UsuarioBanco("Bob", 50, True)

bob.agregar_dinero(20)              # Bob pasa a tener 70
alicia.transferir_dinero(bob, 80)   # Bob no puede transferir 80 porque tiene 70
alicia.retirar_dinero(50)

print(alicia.nombre, alicia.saldo)
print(bob.nombre, bob.saldo)
# Out:
# El usuario que transfiere no tiene saldo suficiente
# Alicia 50
# Bob 70

# %% [markdown]
# 37.Crea una función llamada procesar_texto que procesa un texto según la opción especificada: contar_palabras ,
# reemplazar_palabras , eliminar_palabra . Estas opciones son otras funciones que tenemos que definir primero y llamar dentro
# de la función procesar_texto .
# Código a seguir:
# 1. Crear una función contar_palabras para contar el número de veces que aparece cada palabra en el texto. Tiene
# que devolver un diccionario.
# 2. Crear una función reemplazar_palabras para remplazar una palabra_original del texto por una palabra_nueva . Tiene
# que devolver el texto con el remplazo de palabras.
# 3. Crear una función eliminar_palabra para eliminar una palabra del texto. Tiene que devolver el texto con la palabra
# eliminada.
# 4. Crear la función procesar_texto que tome un texto, una opción(entre "contar", "reemplazar", "eliminar") y un
# número de argumentos variable según la opción indicada.
# Caso de uso:
# Comprueba el funcionamiento completo de la función procesar_texto

# %%
def contar_palabras(texto):
    palabras = texto.split()
    diccionario = {}

    for palabra in palabras:
        if palabra in diccionario:
            diccionario[palabra] += 1
        else:
            diccionario[palabra] = 1

    return diccionario


def reemplazar_palabras(texto, palabra_original, palabra_nueva):
    return texto.replace(palabra_original, palabra_nueva)


def eliminar_palabra(texto, palabra):
    return texto.replace(palabra, "")


def procesar_texto(texto, opcion, *args):
    if opcion == "contar":
        return contar_palabras(texto)
    elif opcion == "reemplazar":
        if len(args) < 2:
            return "Faltan argumentos"
        return reemplazar_palabras(texto, args[0], args[1])
    elif opcion == "eliminar":
        return eliminar_palabra(texto, args[0])
    else:
        return "Opción no válida"

# %%
texto = "hola mundo hola python"

print(procesar_texto(texto, "contar"))
print(procesar_texto(texto, "reemplazar", "hola", "adios"))
print(procesar_texto(texto, "eliminar", "mundo"))
# Out:
# {'hola': 2, 'mundo': 1, 'python': 1}
# adios mundo adios python
# hola  hola python

# %% [markdown]
# 38. Genera un programa que nos diga si es de noche, de día o tarde según la hora proporcionada por el usuario

# %%
hora = int(input("¿Qué hora es?: "))

if 8 < hora < 14:
    print("Es de día")
elif 14 <= hora < 20:
    print("Es por la tarde")
else:
    print("Es de noche")
# Out:
# Es de noche

# %% [markdown]
# 39. Escribe un programa que determine qué calificación en texto tiene un alumno en base a su calificación numérica.
# Las reglas de calificación son:
# - 0 - 69 insuficiente
# - 70 - 79 bien
# - 80 - 89 muy bien
# - 90 - 100 excelente

# %%
nota = int(input("Introduce la nota del alumno: "))

if 0 <= nota <= 69:
    print("La nota es insuficiente")
elif 70 <= nota <= 79:
    print("La nota es bien")
elif 80 <= nota <= 89:
    print("La nota es muy bien")
elif 90 <= nota <= 100:
    print("La nota es excelente")
else:
    print("Nota fuera de rango")
# Out:
# La nota es insuficiente

# %% [markdown]
# 40.Escribe una función que tome dos parámetros: figura (una cadena que puede ser "rectangulo" , "circulo" o
# "triangulo" ) y datos (una tupla con los datos necesarios para calcular el área de la figura).

# %%
import math

def area_figura(figura, datos):
    if figura == "rectangulo":
        base, altura = datos
        return base * altura
    elif figura == "circulo":
        radio = datos[0]
        return math.pi * radio ** 2
    elif figura == "triangulo":
        base, altura = datos
        return (base * altura) / 2
    else:
        return "Figura no válida"

print(area_figura("rectangulo", (5, 3)))
print(area_figura("circulo", (4,)))
print(area_figura("triangulo", (6, 2)))
# Out:
# 15
# 50.26548245743669
# 6.0

# %% [markdown]
# 41. En este ejercicio, se te pedirá que escribas un programa en Python que utilice condicionales para determinar el
# monto final de una compra en una tienda en línea, después de aplicar un descuento. El programa debe hacer lo
# siguiente:
# 1. Solicita al usuario que ingrese el precio original de un artículo.
# 2. Pregunta al usuario si tiene un cupón de descuento (respuesta sí o no).
# 3. Si el usuario responde que sí, solicita que ingrese el valor del cupón de descuento.
# 4. Aplica el descuento al precio original del artículo, siempre y cuando el valor del cupón sea válido (es decir, mayor
# a cero). Por ejemplo, descuento de 15€.
# 5. Muestra el precio final de la compra, teniendo en cuenta el descuento aplicado o sin él.
# 6. Recuerda utilizar estructuras de control de flujo como if, elif y else para llevar a cabo estas acciones en tu
# programa de Python.

# %%
precio_original = int(input("El precio original del articulo es:"))
print(f"El precio del producto es {precio_original}")
cupon_descuento =input("¿Tienes descuento?:").lower()
print(cupon_descuento)
if cupon_descuento == "si":
    solicitud= int(input("Ingrese el descuento:"))
    print(f"El descuento es de {solicitud}")
    if solicitud >0:
        precio_original -=solicitud
        print(f"El precio final es de {precio_original}")
    else: 
        print(f"El precio final es de {precio_original}")
else:
    pass
# Out:
# El precio del producto es 67
# no
